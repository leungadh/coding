# %% [markdown]
# # FastAI Cookbook Ch 2. Examining image datasets in fast.ai
# > Walkthrough of how to examine image datasets using the facilities in fast.ai.
#
# - toc:true
# - branch: master
# - badges: true
# - comments: true
# - author: Mark Ryan
# - categories: [fastai, cookbook, image]

# %%
# imports for notebook boilerplate
# !pip install -Uqq fastbook
import fastbook
from fastbook import *
from fastai.vision.all import *
# Out:
#      |████████████████████████████████| 720 kB 5.0 MB/s
#      |████████████████████████████████| 189 kB 48.3 MB/s
#      |████████████████████████████████| 1.2 MB 45.4 MB/s
#      |████████████████████████████████| 48 kB 4.5 MB/s
#      |████████████████████████████████| 55 kB 3.7 MB/s
#      |████████████████████████████████| 51 kB 291 kB/s
#      |████████████████████████████████| 561 kB 50.2 MB/s
#      |████████████████████████████████| 130 kB 55.8 MB/s

# %%
# set up the notebook for fast.ai
fastbook.setup_book()
# Out:
# Mounted at /content/gdrive

# %%
# ingest the curated image dataset FLOWERS
path = untar_data(URLs.FLOWERS)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='345243648' class='' max='345236087' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [345243648/345236087 00:07<00:00]
#     </div>

# %%
# examine the directory structure of the dataset
path.ls()
# Out:
# (#4) [Path('/root/.fastai/data/oxford-102-flowers/jpg'),Path('/root/.fastai/data/oxford-102-flowers/test.txt'),Path('/root/.fastai/data/oxford-102-flowers/valid.txt'),Path('/root/.fastai/data/oxford-102-flowers/train.txt')]

# %%
# ingest the train dataset list into a Pandas dataframe

df_valid = pd.read_csv(path/'valid.txt', header=None)
df_valid.head()
# Out:
#                         0
# 0  jpg/image_04467.jpg 89
# 1  jpg/image_07129.jpg 44
# 2   jpg/image_05166.jpg 4
# 3  jpg/image_07002.jpg 34
# 4  jpg/image_02007.jpg 79

# %%
# examine the jpg subdirectory
(path/'jpg').ls()
# Out:
# (#8189) [Path('/root/.fastai/data/oxford-102-flowers/jpg/image_03828.jpg'),Path('/root/.fastai/data/oxford-102-flowers/jpg/image_07661.jpg'),Path('/root/.fastai/data/oxford-102-flowers/jpg/image_03860.jpg'),Path('/root/.fastai/data/oxford-102-flowers/jpg/image_02212.jpg'),Path('/root/.fastai/data/oxford-102-flowers/jpg/image_06350.jpg'),Path('/root/.fastai/data/oxford-102-flowers/jpg/image_05954.jpg'),Path('/root/.fastai/data/oxford-102-flowers/jpg/image_07130.jpg'),Path('/root/.fastai/data/oxford-102-flowers/jpg/image_05585.jpg'),Path('/root/.fastai/data/oxford-102-flowers/jpg/image_03449.jpg'),Path('/root/.fastai/data/oxford-102-flowers/jpg/image_02132.jpg')...]

# %%
# take a look at one of the images
img_files = get_image_files(path)
img = PILImage.create(img_files[100])
img
# Out:
# PILImage mode=RGB size=663x500

# %%
# display a thumbnail of the image
img.to_thumb(180)
# Out:
# <PIL.Image.Image image mode=RGB size=180x136 at 0x7F17F12C2DD0>

# %%
# ingest the curated image localization dataset BIWI_HEAD_POSE
path = untar_data(URLs.BIWI_HEAD_POSE)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='452321280' class='' max='452316199' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [452321280/452316199 00:10<00:00]
#     </div>

# %%
# examine the directory structure of the dataset
path.ls()
# Out:
# (#50) [Path('/root/.fastai/data/biwi_head_pose/10.obj'),Path('/root/.fastai/data/biwi_head_pose/08.obj'),Path('/root/.fastai/data/biwi_head_pose/24'),Path('/root/.fastai/data/biwi_head_pose/05.obj'),Path('/root/.fastai/data/biwi_head_pose/13.obj'),Path('/root/.fastai/data/biwi_head_pose/03'),Path('/root/.fastai/data/biwi_head_pose/18'),Path('/root/.fastai/data/biwi_head_pose/19'),Path('/root/.fastai/data/biwi_head_pose/11'),Path('/root/.fastai/data/biwi_head_pose/20.obj')...]

# %%
# examine one of the subdirectories
(path/"05").ls()
# Out:
# (#1894) [Path('/root/.fastai/data/biwi_head_pose/05/frame_00181_pose.txt'),Path('/root/.fastai/data/biwi_head_pose/05/frame_00007_rgb.jpg'),Path('/root/.fastai/data/biwi_head_pose/05/frame_00721_rgb.jpg'),Path('/root/.fastai/data/biwi_head_pose/05/frame_00514_pose.txt'),Path('/root/.fastai/data/biwi_head_pose/05/frame_00751_rgb.jpg'),Path('/root/.fastai/data/biwi_head_pose/05/frame_00246_rgb.jpg'),Path('/root/.fastai/data/biwi_head_pose/05/frame_00580_rgb.jpg'),Path('/root/.fastai/data/biwi_head_pose/05/frame_00890_pose.txt'),Path('/root/.fastai/data/biwi_head_pose/05/frame_00193_pose.txt'),Path('/root/.fastai/data/biwi_head_pose/05/frame_00242_pose.txt')...]

# %%
# take a look at one of the images
img_files = get_image_files(path/'10')
img = PILImage.create(img_files[8])
img.to_thumb(180)
# Out:
# <PIL.Image.Image image mode=RGB size=180x135 at 0x7F17F246FC10>

# %%
# take a look at one of the pose text files
path/'05/frame_00191_pose.txt'
# Out:
# Path('/root/.fastai/data/biwi_head_pose/05/frame_00191_pose.txt')

# %%
# ingest one of the pose text files into a Pandas dataframe
df_pose = pd.read_csv(path/'05/frame_00191_pose.txt', header=None)
df_pose.head()
# Out:
#                                0
# 0   0.860993 0.162766 -0.481869
# 1  0.00729371 0.943363 0.331682
# 2   0.508564 -0.289091 0.811042
# 3       116.403 12.1671 871.544
